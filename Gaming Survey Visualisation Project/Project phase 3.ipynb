# %%
import pandas as pd

# %%
df = pd.read_excel("/Users/tarunrn/Desktop/SEM 2/IFT 533/Project/Updated_Gaming_Survey_Responses.xlsx")
df
# Out:
#                   Timestamp  Age  Gender                Location  \
# 0   2024-10-24 13:09:27.109   18    Male               Bangalore
# 1   2024-10-24 13:09:34.343   19    Male  Hell road , Bangalore
# 2   2024-10-24 13:23:13.403   19    Male               Bangalore
# 3   2024-10-24 13:30:42.445   18  Female                Banglore
# 4   2024-10-24 13:32:26.815   18  Female    Banglore, Karnataka
# ..                      ...  ...     ...                     ...
# 495 2024-10-25 16:55:00.000   19    Male                 Florida
# 496 2024-10-25 16:56:00.000   16  Female                 Florida
# 497 2024-10-25 16:57:00.000   30    Male                    Ohio
# 498 2024-10-25 16:58:00.000   19    Male                    Ohio
# 499 2024-10-25 16:59:00.000   19  Female                 Toronto
#
#       How often do you play video games?    \
# 0                                    Daily
# 1                             Rarely/Never
# 2                             Rarely/Never
# ...

# %%
df.isnull().sum(axis=0)
# Out:
# Timestamp                                                                                       0
# Age                                                                                             0
# Gender                                                                                          0
# Location                                                                                        0
#   How often do you play video games?                                                            0
#   How many hours do you typically spend gaming in a week?                                       0
#   Which device do you play games on the most?(Check all that apply)                             0
# What genres of video games do you play? (Check all that apply)                                  0
#   What is your favorite game?                                                                   0
# How do you discover new games? (Check all that apply)                                           0
# ...

# %%
print(df.columns)
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Location',
#        '  How often do you play video games?  ',
#        '  How many hours do you typically spend gaming in a week?  ',
#        '  Which device do you play games on the most?(Check all that apply)  ',
#        'What genres of video games do you play? (Check all that apply)  ',
#        '  What is your favorite game?  ',
#        'How do you discover new games? (Check all that apply)  ',
#        '  Do you prefer single-player or multiplayer games?  ',
#        ' How much do you spend on gaming monthly (including in-game purchases, new games, etc.)?  ',
#        'Why do you play video games? (Check all that apply)  ',
#        'How many hours do you typically spend gaming in a week?',
#        'Which device do you play games on the most?(Check all that apply)',
#        'What genres of video games do you play? (Check all that apply)',
#        'What is your favorite game?',
# ...

# %%
df = df.drop(['Timestamp',"How many hours do you typically spend gaming in a week?", 
              "Which device do you play games on the most?(Check all that apply)",
              'What genres of video games do you play? (Check all that apply)',
              'What is your favorite game?',
              'How do you discover new games? (Check all that apply)',
              'Do you prefer single-player or multiplayer games?',
              'How much do you spend on gaming monthly (including in-game purchases, new games, etc.)?',
              'Why do you play video games? (Check all that apply)', 'How often do you play video games?'], axis = 1)
df
# Out:
#      Age  Gender                Location  \
# 0     18    Male               Bangalore
# 1     19    Male  Hell road , Bangalore
# 2     19    Male               Bangalore
# 3     18  Female                Banglore
# 4     18  Female    Banglore, Karnataka
# ..   ...     ...                     ...
# 495   19    Male                 Florida
# 496   16  Female                 Florida
# 497   30    Male                    Ohio
# 498   19    Male                    Ohio
# 499   19  Female                 Toronto
#
#       How often do you play video games?    \
# 0                                    Daily
# 1                             Rarely/Never
# 2                             Rarely/Never
# 3                             Rarely/Never
# 4                                    Daily
# ..                                     ...
# 495                           Rarely/Never
# 496                                  Daily
# 497                           Rarely/Never
# ...

# %%
df.isnull().sum(axis=0)
# Out:
# Timestamp                                                                                     0
# Age                                                                                           0
# Gender                                                                                        0
# Location                                                                                      0
#   How often do you play video games?                                                          0
#   How many hours do you typically spend gaming in a week?                                     0
#   Which device do you play games on the most?(Check all that apply)                           0
# What genres of video games do you play? (Check all that apply)                                0
#   What is your favorite game?                                                                 0
# How do you discover new games? (Check all that apply)                                         0
# ...

# %%
df["Gender"].value_counts() #preprocessing required
# Out:
# Gender
# Female    268
# Male      191
# male       41
# Name: count, dtype: int64

# %%
df["Location"].value_counts()
# Out:
# Location
# Bangalore                                                              59
# Mumbai                                                                 50
# Delhi                                                                  48
# New York                                                               36
# Ohio                                                                   32
# London                                                                 32
# Florida                                                                30
# Toronto                                                                25
# Texas                                                                  25
# Hyderabad                                                              20
# Pune                                                                   20
# Kolkata                                                                19
# Chennai                                                                18
# ...

# %%
df["  How often do you play video games?  "].value_counts() #preprocessing required
# Out:
#   How often do you play video games?
# Daily                     209
# Rarely/Never              121
# A few times in a week      80
# A few times a week         70
# A few times in a month     20
# Name: count, dtype: int64

# %%
df["  How many hours do you typically spend gaming in a week?  "].value_counts() #preprocessing required
# Out:
#   How many hours do you typically spend gaming in a week?
# 5-10 hours            161
# 10-20 hours           135
# Less than 5 hours     112
# More than 20 hours     80
# 0                       6
# 30mins                  6
# Name: count, dtype: int64

# %%
df["  Which device do you play games on the most?(Check all that apply)  "].value_counts() #preprocessing required
# Out:
#   Which device do you play games on the most?(Check all that apply)
# Mobile                                                                         130
# PC, Mobile                                                                      89
# Console (PlayStation, Xbox, etc.)                                               55
# Console, Mobile                                                                 55
# PC                                                                              51
# Tablet                                                                          46
# PC, Console                                                                     44
# Console (PlayStation, Xbox, etc.), Mobile                                       10
# Console (PlayStation, Xbox, etc.), Handheld devices (Nintendo Switch, etc.)     10
# PC, Console (PlayStation, Xbox, etc.), Mobile                                   10
# Name: count, dtype: int64

# %%
df["What genres of video games do you play? (Check all that apply)  "].value_counts() #preprocessing required
# Out:
# What genres of video games do you play? (Check all that apply)
# Sports                                                                                                                                                      46
# First-Person Shooter (FPS)                                                                                                                                  45
# Action/Adventure, Role-Playing Games (RPG)                                                                                                                  42
# Action/Adventure, First-Person Shooter (FPS)                                                                                                                40
# Puzzle/Strategy                                                                                                                                             23
# ...

# %%
df["  What is your favorite game?  "].value_counts() #preprocessing required
# Out:
#   What is your favorite game?
# FC MOBILE                    23
# Call of duty                 23
# Subway                       23
# Solo leveling arise          23
# Efootball                    23
# Call of duty                 23
# call of duty                 23
# Wukong                       23
# Rhythm Rush lite             22
# Wuthering waves              22
# CALL OF DUTY                 22
# Solo Levelling               22
# Wuther waves                 22
# Free fire,wuthering waves    22
# Moba Legends                 22
# BGMI                         22
# Red dead redemption 2        20
# Chess and clash of clans     20
# God of war ragnarok          20
# fornite                      20
# bgmi,coc,chess               20
# efootball                    20
# Many                         20
# Name: count, dtype: int64

# %%
df["How do you discover new games? (Check all that apply)  "].value_counts() #preprocessing required
# Out:
# How do you discover new games? (Check all that apply)
# Social Media                                                                                                                   113
# Friends/Family Recommendations                                                                                                  85
# Social Media, Gaming Forums                                                                                                     45
# Gaming Forums, Game Reviews/Blogs                                                                                               44
# Social Media, Friends/Family Recommendations                                                                                    42
# Gaming Forums                                                                                                                   23
# Social Media, Gaming Forums, Game Reviews/Blogs, YouTube/Streaming platforms (Twitch, etc.)                                     23
# ...

# %%
df["  Do you prefer single-player or multiplayer games?  "].value_counts()
# Out:
#   Do you prefer single-player or multiplayer games?
# Both             263
# Multiplayer      155
# Single-player     82
# Name: count, dtype: int64

# %%
df[" How much do you spend on gaming monthly (including in-game purchases, new games, etc.)?  "].value_counts() #preprocessing required
# Out:
#  How much do you spend on gaming monthly (including in-game purchases, new games, etc.)?
# Less than ₹100     181
# ₹100-500           126
# ₹500-1000          100
# More than ₹1000     87
# ₹1000 and above      6
# Name: count, dtype: int64

# %%
df["Why do you play video games? (Check all that apply)  "].value_counts()
# Out:
# Why do you play video games? (Check all that apply)
# For fun/entertainment                                                                                 80
# For fun/entertainment, To relieve stress                                                              73
# For fun/entertainment, To relieve stress, To socialize with friends, To improve skills/competition    56
# To relieve stress                                                                                     54
# To improve skills/competition                                                                         22
# For fun/entertainment, To improve skills/competition                                                  22
# To improve skills/competition, To socialize                                                           20
# To socialize                                                                                          17
# ...
